# %%
import pandas as pd

# %%
data = pd.read_csv("thairath_news.csv")

# %%
data
# Out:
#                                                 title  \
# 0   "กัน จอมพลัง" เข้าเยี่ยมลุง-ป้ากระบะ ฝากถึง "เ...
# 1                                             ทั่วไทย
# 2   คม มท. ชื่นชม “อนุทิน” จัดสอบนายอำเภอโปร่งใส ส...
# 3                                            การเมือง
# 4   “ธรรมนัส” หาเสียงช่วย “บิ๊กโอ” ยืนยันใจนักเลง ...
# 5   รวบแล้วมือกรีดร่างพระเลือดสาดก่อนจุดไฟเผา ยอมร...
# 6   ปฏิบัติการ “สิงห์สายลับ” ทลายบุหรี่เถื่อนภูเก็...
# 7                                           อาชญากรรม
# 8   รองผู้ว่าฯ กทม. ยันรื้อซากตึก สตง. ทันสิ้น เม....
# 9                                                กทม.
# 10  “เต้ มงคลกิตติ์” ออกโรงเตือน “กัน จอมพลัง” คดี...
# 11  อวสานสายหื่น พูดคุกคามสาววิ่งออกกำลังกาย สุดท้...
# 12                                            ในกระแส
# 13  หนุ่มร้องไห้จะวิ่งเข้ากองเพลิง หวังช่วยสัตว์เล...
# 14  ปัดเพื่อไทยดีลดึงกระทรวงมหาดไทยจากภูมิใจไทย รั...
# 15  ปลื้ม นักท่องเที่ยวชมบูธ “สมุนไพร - นวดไทย” โอ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       57 non-null     object
#  1   url         57 non-null     object
#  2   scraped_at  57 non-null     object
#  3   published   0 non-null      float64
#  4   content     50 non-null     object
#  5   tags        0 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 2.8+ KB

# %%
data["content"].apply(lambda x: len(str(x))).plot.hist(title="charactor lenght of content")
# Out:
# <Axes: title={'center': 'charactor lenght of content'}, ylabel='Frequency'>
